# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading csv for GDP
df_GDP = pd.read_csv('NEWDATA (2).csv')
df_GDP
# Out:
#              Country   nominal GDP abbrev GDP  GDP growth  Population  \
# 0      United States  1.948540e+13  19,485.00      0.0227   325084756
# 1              China  1.223770e+13  12,238.00      0.0690  1421021791
# 2              Japan  4.872420e+12   4,872.00      0.0171   127502725
# 3            Germany  3.693200e+12   3,693.00      0.0222    82658409
# 4              India  2.650730e+12   2,651.00      0.0668  1338676785
# ..               ...           ...        ...         ...         ...
# 172           Gambia  1.489465e+09       1.49      0.0456     2213889
# 173    Guinea-Bissau  1.346842e+09       1.35      0.0592     1828145
# 174  Solomon Islands  1.303454e+09        1.3      0.0324      636039
# 175          Grenada  1.126882e+09       1.13      0.0506      110874
# 176          Comoros  1.068124e+09       1.07      0.0271      813892
#
#      GDP per captial  Share of World GDP        Lat         Lng  \
# 0              59939              0.2408  39.783730 -100.445882
# 1               8612              0.1512  35.000074  104.999927
# 2              38214              0.0602  36.574844  139.239418
# 3              44680              0.0456  51.163818   10.447831
# 4               1980              0.0328  22.351115   78.667743
# ..               ...                 ...        ...         ...
# 172              673              0.0000  13.470062  -15.490046
# 173              737              0.0000  11.815215  -15.235104
# 174             2049              0.0000  -8.705394  159.107069
# 175            10164              0.0000  12.136037  -61.690404
# 176             1312              0.0000 -12.204518   44.283296
#
#                        Country Size     Continents
# 0         Super Large(>10 trllions)  North America
# 1         Super Large(>10 trllions)           Asia
# 2    Large (1 trllions-10 trllions)           Asia
# 3    Large (1 trllions-10 trllions)         Europe
# 4    Large (1 trllions-10 trllions)           Asia
# ..                              ...            ...
# 172           Small (<100 billions)         Africa
# 173           Small (<100 billions)         Africa
# 174           Small (<100 billions)        Oceania
# 175           Small (<100 billions)  North America
# 176           Small (<100 billions)         Africa
#
# [177 rows x 11 columns]

# %%
# Checking the number of countries.
num_country = df_GDP["Country"].nunique()
num_country
# Out:
# 177

# %%
# sorting the values for nominal GDP
Topcountry_df=df_GDP.sort_values(["nominal GDP" ], ascending=False)
Topcountry_df.head()
# Out:
#          Country   nominal GDP abbrev GDP  GDP growth  Population  \
# 0  United States  1.948540e+13  19,485.00      0.0227   325084756
# 1          China  1.223770e+13  12,238.00      0.0690  1421021791
# 2          Japan  4.872420e+12   4,872.00      0.0171   127502725
# 3        Germany  3.693200e+12   3,693.00      0.0222    82658409
# 4          India  2.650730e+12   2,651.00      0.0668  1338676785
#
#    GDP per captial  Share of World GDP        Lat         Lng  \
# 0            59939              0.2408  39.783730 -100.445882
# 1             8612              0.1512  35.000074  104.999927
# 2            38214              0.0602  36.574844  139.239418
# 3            44680              0.0456  51.163818   10.447831
# 4             1980              0.0328  22.351115   78.667743
#
#                      Country Size     Continents
# 0       Super Large(>10 trllions)  North America
# 1       Super Large(>10 trllions)           Asia
# 2  Large (1 trllions-10 trllions)           Asia
# 3  Large (1 trllions-10 trllions)         Europe
# 4  Large (1 trllions-10 trllions)           Asia

# %%
#comparision of Ten countries with nominal GDP
countries = Topcountry_df.iloc[0:10]
countries= countries [["Country","nominal GDP"]]

# %% [markdown]
# # Plotting Bar chats

# %%
#plotting on bar chart
plot_pandas = countries.plot.bar(color='b')  
plt.xlabel("country")
plt.ylabel("nominal GDP")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
# sorting the values for GDP per captial
Topcountry_df=df_GDP.sort_values(["GDP per captial" ], ascending=False)
Topcountry_df.head()
# Out:
#          Country   nominal GDP abbrev GDP  GDP growth  Population  \
# 71    Luxembourg  6.231636e+10      62.32      0.0230      591910
# 81         Macao  5.036120e+10      50.36      0.0910      622585
# 19   Switzerland  6.789650e+11        679      0.0109     8455804
# 27        Norway  3.994890e+11        399      0.0192     5296326
# 104      Iceland  2.448847e+10      24.49      0.0364      334393
#
#      GDP per captial  Share of World GDP        Lat         Lng  \
# 71            105280              0.0008  49.815868    6.129675
# 81             80890              0.0006  22.139833  113.563619
# 19             80296              0.0084  46.798562    8.231974
# 27             75428              0.0049  61.152939    8.787665
# 104            73233              0.0003  64.984182  -18.105901
#
#                          Country Size Continents
# 71              Small (<100 billions)     Europe
# 81              Small (<100 billions)       Asia
# 19   Medium (100 billions-1 trllions)     Europe
# 27   Medium (100 billions-1 trllions)     Europe
# 104             Small (<100 billions)     Europe

# %%
#comparision of Ten countries with GDP per captia
countries = Topcountry_df.iloc[0:10]
countries= countries [["Country","GDP per captial"]]

# %%
#plotting on bar chart
plot_pandas = countries.plot.bar(color='b')  
plt.xlabel("country")
plt.ylabel("GDP per captial")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
# sorting the values for Population
Topcountry_df=df_GDP.sort_values(["Population" ], ascending=False)
Topcountry_df.head()
# Out:
#           Country   nominal GDP abbrev GDP  GDP growth  Population  \
# 1           China  1.223770e+13  12,238.00      0.0690  1421021791
# 4           India  2.650730e+12   2,651.00      0.0668  1338676785
# 0   United States  1.948540e+13  19,485.00      0.0227   325084756
# 15      Indonesia  1.015420e+12   1,015.00      0.0507   264650963
# 39       Pakistan  3.049520e+11        305      0.0570   207906209
#
#     GDP per captial  Share of World GDP        Lat         Lng  \
# 1              8612              0.1512  35.000074  104.999927
# 4              1980              0.0328  22.351115   78.667743
# 0             59939              0.2408  39.783730 -100.445882
# 15             3837              0.0125  -2.483383  117.890285
# 39             1467              0.0038  30.330840   71.247499
#
#                         Country Size     Continents
# 1          Super Large(>10 trllions)           Asia
# 4     Large (1 trllions-10 trllions)           Asia
# 0          Super Large(>10 trllions)  North America
# 15    Large (1 trllions-10 trllions)           Asia
# 39  Medium (100 billions-1 trllions)           Asia

# %%
#comparision of Ten countries Population
countries = Topcountry_df.iloc[0:10]
countries= countries [["Country","Population"]]

# %%
#plotting on bar chart
plot_pandas = countries.plot.bar(color='b')  
plt.xlabel("country")
plt.ylabel("Population")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
#comparision of Ten Continents Population
Continents = TopContinents_df.iloc[0:10]
Continents= Continents [["Continents","Population"]]

# %%
#plotting on bar chart
plot_pandas =Continents .plot.bar(color='b')  
plt.xlabel("Continents")
plt.ylabel("Population")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
#comparision of Ten Continents with nominal GDP
Continents = TopContinents_df.iloc[0:10]
Continents= Continents [["Continents","nominal GDP"]]

# %%
#plotting on bar chart
plot_pandas =Continents .plot.bar(color='b')  
plt.xlabel("Continents")
plt.ylabel("nominal GDP")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
#comparision of Ten Continents with GDP growth
Continents = TopContinents_df.iloc[0:10]
Continents= Continents [["Continents","GDP growth"]]

# %%
#plotting on bar chart
plot_pandas =Continents .plot.bar(color='b')  
plt.xlabel("Continents")
plt.ylabel("GDP growth")
plt.title("GDP")
# Out:
# Text(0.5, 1.0, 'GDP')

# %% [markdown]
# # Summary statistics

# %%
mean = df_GDP['Population'].groupby(df_GDP['Continents']).mean()

# %%
#Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of POPULATIONfor each Continent
mean = df_GDP['Population'].groupby(df_GDP['Continents']).mean()
median = df_GDP['Population'].groupby(df_GDP['Continents']).median()
var = df_GDP['Population'].groupby(df_GDP['Continents']).var()
std = df_GDP['Population'].groupby(df_GDP['Continents']).std()
sem = df_GDP['Population'].groupby(df_GDP['Continents']).sem()
summary_stat = pd.DataFrame({"mean Population":mean, 
                            "median Population":median, 
                           "Population Variance":var, 
                           "Population Std. Dev.":std, 
                           "Population Std. Err.":sem})
# Display the Summary statistics
summary_stat.head()
# Out:
#                mean Population  median Population  Population Variance  \
# Continents
# Africa            2.502054e+07         14236595.0         1.226251e+15
# Asia              9.879447e+07         16009409.0         8.135591e+16
# Europe            1.747209e+07          5621822.5         8.481650e+14
# North America     2.683933e+07          5667400.0         5.138539e+15
# Oceania           7.720728e+06          2972646.0         9.413134e+13
#
#                Population Std. Dev.  Population Std. Err.
# Continents
# Africa                 3.501787e+07          5.107881e+06
# Asia                   2.852296e+08          4.251951e+07
# Europe                 2.912327e+07          4.493819e+06
# North America          7.168361e+07          1.528300e+07
# Oceania                9.702131e+06          3.068083e+06

# %% [markdown]
# # Scatter plots

# %%
# Build scatter plot for lat vs. lng
plt.scatter(     
    df_GDP["Lat"],
   df_GDP ["Lng"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Country"
)

# Incorporate the other graph properties
plt.title("GDP")
plt.xlabel("Lat")
plt.ylabel("lng")
plt.grid(True)


# Show plot
plt.show()

# %%
# Build scatter plot for Share of world GDP VS. GDP growth
plt.scatter(     
    df_GDP["Share of World GDP"],
   df_GDP ["GDP growth"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="GDP"
)

# Incorporate the other graph properties
plt.title(" GDP")
plt.xlabel("GDP growth")
plt.ylabel("Share of World GDP")
plt.grid(True)


# Show plot
plt.show()

# %%
# Build scatter plot for Share of world GDP VS. GDP growth
plt.scatter(     
    df_GDP["Continents"],
   df_GDP ["Population"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="GDP"
)

# Incorporate the other graph properties
plt.title(" GDP")
plt.xlabel("Continents")
plt.ylabel("Population")
plt.grid(True)


# Show plot
plt.show()
